# %%
import pandas as pd
import json
import numpy as np

# %%
def list_toString(column, prefix):
    # Aplicar la función join a cada celda de la columna
    celda = column.apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
    celda=celda.str.replace(prefix, '').str.strip()
    return celda

def dic_toString(column,prefix):
    # Aplicar la función json.dumps a cada celda de la columna
    celda = column.apply(lambda x: json.dumps(x) if isinstance(x, dict) else x)
    celda=celda.str.replace(prefix, '').str.strip()
    return celda

# %%
df_original=pd.read_json('train_products.json')

# %%
#se traspone el dataframe para una mejor comprension
df=df_original.T

# %%
#se reemplazó unknown por NA
df = df.applymap(lambda x: pd.NA if x == 'unknown' else x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 2
#       1 #se reemplazó unknown por NA
# ----> 2 df = df.applymap(lambda x: pd.NA if x == 'unknown' else x)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:9653, in DataFrame.applymap(self, func, na_action, **kwargs)
#    9650         return lib.map_infer(x, func, ignore_na=ignore_na)
#    9651     return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
# -> 9653 return self.apply(infer).__finalize__(self, "applymap")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# ...

# %%
df['categories_hierarchy']= list_toString(df['categories_hierarchy'],'en:')
df['selling_countries'] = list_toString(df['selling_countries'], 'en:')

# %%
df['ingredient_origins'] = dic_toString(df['ingredient_origins'],'en:')
df['ingredient_origins'] = dic_toString(df['ingredient_origins'],'en:unknown')

# %%
df['ingredient_origins'] = df['ingredient_origins'].str.replace(prefix, '').str.strip()

# %%
df['packaging_materials']= list_toString(df['packaging_materials'],'en:')

# %%
print(df['ingredient_origins'][20830])
# Out:
# {"france": 100}

# %%
df['ingredient_origins'][20830]
# Out:
# '{"france": 100}'

# %%
df['ingredient_origins'].head(10)
# Out:
# 0                        {"unknown": 100}
# 1                        {"unknown": 100}
# 2                        {"unknown": 100}
# 3                        {"unknown": 100}
# 4                        {"unknown": 100}
# 5                        {"unknown": 100}
# 6                        {"unknown": 100}
# 7           {"ireland": 50, "norway": 50}
# 8                 {"european-union": 100}
# 9    {"faroe-islands": 50, "iceland": 50}
# Name: ingredient_origins, dtype: object

# %%
df
# Out:
#                                           name  \
# 0                              Pommes duchesse
# 1        Bûche pâtissière à la crème au beurre
# 2                                   Cini Minis
# 3                      Cuor di fette Carrefour
# 4                                        Curry
# ...                                        ...
# 20830                            jus de pommes
# 20831              Cafe soluble tueste natural
# 20832  Cioccolato fondente con nocciole intere
# 20833        BEURRE MOULÉ DE Bretagne Demi sel
# 20834                          Pechuga de pavo
#
#                                     brand generic_name  \
# 0      Pom lisse,Pom'Lisse, Marque Repère         <NA>
# 1                Esprit de Fête,Carrefour         <NA>
# 2                          Nestlé, Nestlé
# 3                               Carrefour         <NA>
# 4              Carrefour,Groupe Carrefour         <NA>
# ...                                   ...          ...
# ...
